# %% [markdown]
# ## REGRESION LINEAL 200 DATOS PRACTICA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("practica.csv")

# %%
df
# Out:
#      Altura (pulgadas)  Peso (Libras)
# 0                65.78         112.99
# 1                71.52         136.49
# 2                69.40         153.03
# 3                68.22         142.34
# 4                67.79         144.30
# ..                 ...            ...
# 195              65.80         120.84
# 196              66.11         115.78
# 197              68.24         128.30
# 198              68.02         127.47
# 199              71.39         127.88
#
# [200 rows x 2 columns]

# %%
# %matplotlib inline 
plt.plot(df,'b.')
plt.show()

# %%
plt.plot(df['Altura (pulgadas)'], df['Peso (Libras)'],'b.')
plt.xlabel("Altura Pulgadas")
plt.ylabel("Peso en Libras")
# Out:
# Text(0, 0.5, 'Peso en Libras')

# %%
from sklearn.linear_model import LinearRegression

# %%
# Construcción del modelo y ajuste de la función de hipótesis
lin_reg = LinearRegression()
lin_reg.fit(df['Altura (pulgadas)'].values.reshape(-1,1),(df['Peso (Libras)'].values))
# Out:
# LinearRegression()

# %%
# Parámetro Theta 0 
lin_reg.intercept_
# Out:
# -106.02770644878126

# %%
# Parámetro Theta 1
lin_reg.coef_
# Out:
# array([3.43267613])

# %%
# Predicción para el valor mínimo y máximo del conjunto de datos de entrenamiento
x_min_mx = np.array([[df["Altura (pulgadas)"].min()],[df["Altura (pulgadas)"].max()]])
y_train_pred = lin_reg.predict(x_min_mx)

# %%
# Representación gráfica de la función hipótesis generada
plt.plot(x_min_mx, y_train_pred,"g-")
plt.plot(df["Altura (pulgadas)"], df["Peso (Libras)"], "b.")
plt.xlabel("Altura (pulgadas)")
plt.ylabel("Peso (Libras)")
plt.show()

# %%
x_new = np.array([[79]]) 
#Predicción del costo que tendría el incidente
Peso = lin_reg.predict(x_new)
print("El peso sería de: ", int(Peso[0]))
# Out:
# El peso sería de:  165

# %%
plt.plot(df["Altura (pulgadas)"], df["Peso (Libras)"], "b.")
plt.plot(x_min_mx, y_train_pred, "g-")
plt.plot(x_new, Peso, "rx")
plt.xlabel("Altura (pulgadas)")
plt.ylabel("Peso (Libras)")
plt.show()
